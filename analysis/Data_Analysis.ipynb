# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_cleaned = pd.read_csv("df_cleaned.csv")
df = pd.read_csv('student_dropout_dataset_v3.csv')

# %%
boxplot = df.boxplot(figsize=(15,10))
boxplot.set_xticklabels(boxplot.get_xticklabels(), rotation=90)
# Out:
# [Text(1, 0, 'Age'),
#  Text(2, 0, 'Gender'),
#  Text(3, 0, 'Family_Income'),
#  Text(4, 0, 'Internet_Access'),
#  Text(5, 0, 'Study_Hours_per_Day'),
#  Text(6, 0, 'Attendance_Rate'),
#  Text(7, 0, 'Assignment_Delay_Days'),
#  Text(8, 0, 'Travel_Time_Minutes'),
#  Text(9, 0, 'Part_Time_Job'),
#  Text(10, 0, 'Scholarship'),
#  Text(11, 0, 'Stress_Index'),
#  Text(12, 0, 'GPA'),
#  Text(13, 0, 'Semester_GPA'),
#  Text(14, 0, 'CGPA'),
#  Text(15, 0, 'Dropout')]

# %%
corr = df_encoded.drop(columns=['Dropout']).corr().abs()

plt.figure(figsize=(14, 10))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='RdYlGn',
            center=0, linewidths=0.3)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %%
#Drop highly correlated variables
df_encoded = df_encoded.drop(columns=['GPA', 'Semester_GPA'])

# %%
df_encoded['Dropout'].value_counts()
# Out:
# Dropout
# 0    6902
# 1    2118
# Name: count, dtype: int64

# %%
# Drop outlier: It removes all rows where Family_Income is equal to the maximum value in that column.
df_encoded = df_encoded[df_encoded['Family_Income'] != df_encoded['Family_Income'].max()]

# %%
df_encoded.shape
# Out:
# (9019, 23)

# %%
boxplot2 = df_encoded.boxplot(figsize=(15,10))
boxplot2.set_xticklabels(boxplot2.get_xticklabels(), rotation=90)
plt.show()

# %%
df_encoded.to_csv("df_modeling.csv", index=False)
